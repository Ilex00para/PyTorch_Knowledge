# %% [markdown]
# ### What to save during training?
#
# 1. Meta data
#     - Which data/ scenario?
#     - Which model/archietecture? (save the whole model or state dict)
#     - Which hyperparameters? (LR,Epochs, Regularization penalty)
#     -
# 2. Training development
#     - Training Loss and Validation Loss, RMSE
#
# 3. Predictions on the run
#     - to detect continuous 0 prediction --> val loss does not change training useless
#     ![image.png](attachment:image.png)
#
# 4. Gradients on the run
#     - to detect vanishing gradient problems

# %% [markdown]
# ### Grid Searches
#
# 1. Golden rule:
#     - LR first (can also solve Problems in "What to save during training?" 3 and 4 )
#
# 2. Not kernels just gives you the largest first
#
# 3.

# %% [markdown]
# Shapley Calculations
# What to do?
#
# 1. kmeans clustering for background data set and samples
#
# 2. Different random seeds (since very sample specific)
#
#
# What to save?
#
# 1. Shapley values
#
# 2. Samples used for calculating the shapley values (n, n-kmeans)
